# %%
import numpy as np
A = np.array([1, 2, 3, 4])
print(A)
# Out:
# [1 2 3 4]

# %%
np.ndim(A)   #배열의 차원수
# Out:
# 1

# %%
A.shape     #배열의 형상
# Out:
# (4,)

# %%
A.shape[0]
# Out:
# 4

# %%
B = np.array([[1,2], [3,4], [5,6]])
print(B)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
np.ndim(B)
# Out:
# 2

# %%
B.shape
# Out:
# (3, 2)

# %%
B.shape[1]
# Out:
# 2

# %%
A = np.array([[1,2], [3,4]])
B = np.array([[5,6], [7,8]])

np.dot(A,B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A = np.array([[1,2], [3,4]])
A.shape
# Out:
# (2, 2)

# %%
B = np.array([[1,2,3], [4,5,6]])
B.shape
# Out:
# (2, 3)

# %%
np.dot(A,B)
# Out:
# array([[ 9, 12, 15],
#        [19, 26, 33]])

# %%
C = np.array([[1,2,3], [1,2,3], [1,2,3]])
C.shape
# Out:
# (3, 3)

# %%
np.dot(A,C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-bef0a2d6fb5b> in <module>
# ----> 1 np.dot(A,C)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (3,3) not aligned: 2 (dim 1) != 3 (dim 0)
